# %%
# Three Method to cover 
# df.reset_index()
# df.set_index()
# df.sort_index()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'C:\Users\GEORGE TECHNOLOGY EN\Documents\data_jobs.csv')

# %% [markdown]
#  df.reset_index()

# %%
df.index.name = 'job_index'

# %%
df_usa = df[df['job_country'] == 'United States']

df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
# as you can see in df_usa dataframe the index are not structured and are missing some value 
# and to fix that we will use the reset_index method 
df_usa.reset_index(inplace=True)

# %%
# now if we check the number should be there 
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %% [markdown]
#  df.set_index()

# %%
# if you want to set job_index as the main index then you can use the set_index method
# df_usa.set_index('job_index', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9200\1455466831.py in ?()
#       1 # if you want to go back to that Job_index column the set method can be used to achieve that
# ----> 2 df_usa.set_index('job_index', inplace=True)
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['job_index'] are in the columns"

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %% [markdown]
# Sort_ index

# %%
df_stat = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median','min','max'])

# %%
df_stat
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0         16500.0        387460.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Senior Data Scientist            155500.0         45000.0        890000.0
# Software Engineer                 99150.0         28000.0        375000.0

# %%
df_stat.sort_values(by=('median','salary_year_avg'), ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155500.0         45000.0        890000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Software Engineer                 99150.0         28000.0        375000.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Business Analyst                  85000.0         16500.0        387460.0
