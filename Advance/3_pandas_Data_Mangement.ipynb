# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'C:\Users\GEORGE TECHNOLOGY EN\Documents\data_jobs.csv')

# %%
# sample method returns a random sample of items form an object(.sample())
df.sample()
# Out:
#              job_title_short                                    job_title  \
# 307021  Senior Data Engineer  Senior Data Engineer - Cloud Transformation
#
#        job_location       job_via job_schedule_type  job_work_from_home  \
# 307021   London, UK  via LinkedIn        Contractor               False
#
#        search_location      job_posted_date  job_no_degree_mention  \
# 307021  United Kingdom  2023-07-10 17:36:50                  False
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 307021                 False  United Kingdom         NaN              NaN
#
#         salary_hour_avg company_name  \
# 307021              NaN     DATAHEAD
#
#                                                job_skills  \
# 307021  ['sql', 'python', 'swift', 'azure', 'databrick...
#
#                                           job_type_skills
# 307021  {'analyst_tools': ['ssis'], 'cloud': ['azure',...

# %%
# to get a specific number of random items this is an example
df.sample(10)

# %%
# to get the same random sample 
df.sample(10,random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
# copy method makes a copy of the object indicies and data. this is good because this does not change the original dataframe 
# unlike the (=) method that cahnges the original dataframe due to the (=) method also cpoying the original datframe id
df_flitered = df.copy()

print('the id of df:', id(df))
print('the id of df_flitered:', id(df_flitered))
print('Are the two dataset the sam?:', id(df)==id(df_flitered))
# Out:
# the id of df: 1483919284208
# the id of df_flitered: 1483919661392
# Are the two dataset the sam?: False
